# %% [markdown]
# ## Bactesting bollinger band

# %%
import sys
import os

# Add the parent directory (d:\Trading bot) to the Python path
sys.path.append(os.path.abspath("D:/Trading bot/"))

# %%
import MetaTrader5 as mt5
from datetime import datetime, timedelta, time
from IPython.display import display
from backtester import Backtester, get_ohlc_history, create_price_fig, evaluate_backtest

# %%
symbol = 'USDJPY'
start_dt = datetime(2023, 1, 1)
end_dt = datetime.now()

# get historical data
mt5.initialize()
ohlc = get_ohlc_history(symbol, mt5.TIMEFRAME_D1, start_dt, end_dt)

sma_period = 20 

ohlc['sma_20'] = ohlc['open'].rolling(sma_period).mean()
ohlc['std'] = ohlc['open'].rolling(sma_period).std()

ohlc['upper_band'] = ohlc['sma_20'] + 1.5 * ohlc['std']
ohlc['lower_band'] = ohlc['sma_20'] - 1.5 * ohlc['std']

display(ohlc)

fig = create_price_fig(ohlc, indicators=['sma_20' ,'upper_band', 'lower_band'])
display(fig)
# Out:
#           time     open     high      low    close     sma_20       std  \
# 0   2023-01-02  130.924  131.046  130.601  130.601        NaN       NaN
# 1   2023-01-03  130.698  131.400  129.517  130.985        NaN       NaN
# 2   2023-01-04  131.014  132.716  129.926  132.652        NaN       NaN
# 3   2023-01-05  132.570  134.055  131.684  133.421        NaN       NaN
# 4   2023-01-06  133.406  134.774  131.998  132.106        NaN       NaN
# ..         ...      ...      ...      ...      ...        ...       ...
# 661 2025-07-21  147.844  148.667  147.081  147.334  145.90795  1.678171
# 662 2025-07-22  147.330  147.949  146.310  146.637  145.96860  1.707782
# 663 2025-07-23  146.590  147.212  146.109  146.473  146.05320  1.693807
# 664 2025-07-24  146.472  147.019  145.856  146.998  146.11675  1.683966
# 665 2025-07-25  146.992  147.496  146.930  147.257  146.24780  1.642431
#
#      upper_band  lower_band
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 661  148.425207  143.390693
# 662  148.530273  143.406927
# 663  148.593911  143.512489
# 664  148.642698  143.590802
# 665  148.711446  143.784154
#
# [666 rows x 9 columns]

# %%
def get_signal(x):
    if x['open'] > x['upper_band']:
        return 'sell'
    elif x['open'] < x['lower_band']:
        return 'buy'
    

def exit_singnal(x):
    if x['open'] > x['sma_20']:
        return 'close_buy_postion'
    elif x['open'] < x['lower_band']:
        return 'close_sell_postion'
    

ohlc['signal'] = ohlc.apply(get_signal, axis=1)
ohlc['exit_signal'] = ohlc.apply(exit_singnal, axis=1)
ohlc
# Out:
#           time     open     high      low    close     sma_20       std  \
# 0   2023-01-02  130.924  131.046  130.601  130.601        NaN       NaN
# 1   2023-01-03  130.698  131.400  129.517  130.985        NaN       NaN
# 2   2023-01-04  131.014  132.716  129.926  132.652        NaN       NaN
# 3   2023-01-05  132.570  134.055  131.684  133.421        NaN       NaN
# 4   2023-01-06  133.406  134.774  131.998  132.106        NaN       NaN
# ..         ...      ...      ...      ...      ...        ...       ...
# 661 2025-07-21  147.844  148.667  147.081  147.334  145.90795  1.678171
# 662 2025-07-22  147.330  147.949  146.310  146.637  145.96860  1.707782
# 663 2025-07-23  146.590  147.212  146.109  146.473  146.05320  1.693807
# 664 2025-07-24  146.472  147.019  145.856  146.998  146.11675  1.683966
# 665 2025-07-25  146.992  147.496  146.930  147.257  146.24780  1.642431
#
#      upper_band  lower_band signal        exit_signal
# 0           NaN         NaN   None               None
# 1           NaN         NaN   None               None
# 2           NaN         NaN   None               None
# 3           NaN         NaN   None               None
# 4           NaN         NaN   None               None
# ..          ...         ...    ...                ...
# 661  148.425207  143.390693   None  close_buy_postion
# 662  148.530273  143.406927   None  close_buy_postion
# 663  148.593911  143.512489   None  close_buy_postion
# 664  148.642698  143.590802   None  close_buy_postion
# 665  148.711446  143.784154   None  close_buy_postion
#
# [666 rows x 11 columns]

# %%
# create trade logic
def on_bar(data, trades, orders):
    volume = 100000 # 1 lots 
    
    open_trades = trades[trades['state'] == 'open']
    num_open_trades = open_trades.shape[0]
    
    # entry signal 
    if data['signal'] == 'buy' and not num_open_trades:
        orders.open_trade(symbol, volume, 'buy')
    
    elif data['signal'] == 'sell' and not num_open_trades:
        orders.open_trade(symbol, volume, 'sell')
        
    # exit signal
    if num_open_trades:
        trade = open_trades.iloc[0]

        if trade['order_type'] == 'buy' and data['exit_signal'] == 'close_buy_postion':
            orders.close_trade(trade)
        elif trade['order_type'] == 'sell' and data['exit_signal'] == 'close_sell_postion':
            orders.close_trade(trade)

# %%
# backtest parameters
starting_balance = 10000
currency = 'USD'
exchange_rate = 1/150
commission = -7 / 100000

# backtest
bt = Backtester()
bt.set_starting_balance(starting_balance, currency=currency)
bt.set_exchange_rate(exchange_rate)
bt.set_commission(commission)

bt.set_historical_data(ohlc)
bt.set_on_bar(on_bar)

bt.run_backtest()

bt.trades
# Out:
#      state  symbol order_type  volume            open_time open_price  \
# 0   closed  USDJPY       sell  100000  2023-02-06 00:00:00    132.448
# 1   closed  USDJPY        buy  100000  2023-03-16 00:00:00    133.373
# 2   closed  USDJPY       sell  100000  2023-04-17 00:00:00    133.802
# 3   closed  USDJPY        buy  100000  2023-07-13 00:00:00    138.456
# 4   closed  USDJPY       sell  100000  2023-08-03 00:00:00    143.324
# 5   closed  USDJPY        buy  100000  2023-11-22 00:00:00    148.372
# 6   closed  USDJPY       sell  100000  2024-01-11 00:00:00     145.74
# 7   closed  USDJPY        buy  100000  2024-03-08 00:00:00     147.96
# 8   closed  USDJPY       sell  100000  2024-04-11 00:00:00    153.079
# 9   closed  USDJPY       sell  100000  2024-06-20 00:00:00     158.08
# 10  closed  USDJPY        buy  100000  2024-07-19 00:00:00    157.354
# 11  closed  USDJPY        buy  100000  2024-09-05 00:00:00    143.728
# 12  closed  USDJPY       sell  100000  2024-10-03 00:00:00    146.455
# 13  closed  USDJPY        buy  100000  2024-12-02 00:00:00     149.58
# 14  closed  USDJPY       sell  100000  2024-12-20 00:00:00    157.416
# 15  closed  USDJPY        buy  100000  2025-01-21 00:00:00    155.563
# 16  closed  USDJPY        buy  100000  2025-02-21 00:00:00     149.62
# 17  closed  USDJPY       sell  100000  2025-03-25 00:00:00    150.691
# 18  closed  USDJPY        buy  100000  2025-04-07 00:00:00     145.34
# 19  closed  USDJPY       sell  100000  2025-05-09 00:00:00    145.914
#
#              close_time close_price sl tp info   profit commission profit_net  \
# 0   2023-03-14 00:00:00     133.176  0  0   {}  -485.33       -7.0    -492.33
# 1   2023-04-03 00:00:00     133.367  0  0   {}    -4.00       -7.0      -11.0
# 2   2023-07-12 00:00:00     140.376  0  0   {} -4382.67       -7.0   -4389.67
# 3   2023-07-31 00:00:00     140.918  0  0   {}  1641.33       -7.0    1634.33
# 4   2023-11-21 00:00:00     148.323  0  0   {} -3332.67       -7.0   -3339.67
# 5   2024-01-05 00:00:00     144.604  0  0   {} -2512.00       -7.0    -2519.0
# 6   2024-03-07 00:00:00     149.306  0  0   {} -2377.33       -7.0   -2384.33
# 7   2024-03-20 00:00:00     150.809  0  0   {}  1899.33       -7.0    1892.33
# 8   2024-06-05 00:00:00     154.849  0  0   {} -1180.00       -7.0    -1187.0
# 9   2024-07-18 00:00:00     156.165  0  0   {}  1276.67       -7.0    1269.67
# 10  2024-09-02 00:00:00     145.998  0  0   {} -7570.67       -7.0   -7577.67
# 11  2024-09-23 00:00:00     143.838  0  0   {}    73.33       -7.0      66.33
# 12  2024-11-28 00:00:00     151.058  0  0   {} -3068.67       -7.0   -3075.67
# 13  2024-12-12 00:00:00      152.44  0  0   {}  1906.67       -7.0    1899.67
# 14  2025-01-17 00:00:00     155.142  0  0   {}  1516.00       -7.0     1509.0
# 15  2025-02-13 00:00:00     154.409  0  0   {}  -769.33       -7.0    -776.33
# 16  2025-03-18 00:00:00       149.2  0  0   {}  -280.00       -7.0     -287.0
# 17  2025-04-04 00:00:00     146.053  0  0   {}  3092.00       -7.0     3085.0
# 18  2025-05-02 00:00:00     145.383  0  0   {}    28.67       -7.0      21.67
# 19  2025-07-25 00:00:00     147.257  0  0   {}  -895.33       -7.0    -902.33
#
#    profit_cumulative   balance
# 0            -492.33   9507.67
# 1            -503.33   9496.67
# 2            -4893.0    5107.0
# 3           -3258.67   6741.33
# 4           -6598.34   3401.66
# 5           -9117.34    882.66
# 6          -11501.67  -1501.67
# 7           -9609.34    390.66
# 8          -10796.34   -796.34
# 9           -9526.67    473.33
# 10         -17104.34  -7104.34
# 11         -17038.01  -7038.01
# 12         -20113.68 -10113.68
# 13         -18214.01  -8214.01
# 14         -16705.01  -6705.01
# 15         -17481.34  -7481.34
# 16         -17768.34  -7768.34
# 17         -14683.34  -4683.34
# 18         -14661.67  -4661.67
# 19          -15564.0   -5564.0

# %%
pnl_chart = bt.plot_pnl()
pnl_chart

# %%
backtest_fig = bt.visualize_backtest(indicators=['sma_20', 'upper_band', 'lower_band'])
backtest_fig

# %%
evaluate_backtest(bt.trades)
# Out:
# biggest_profit 3092.0
# biggest_loss -7570.67
#      state  symbol order_type  volume  open_time open_price close_time  \
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
#
#     balance
# 3   6741.33
# 7    390.66
# 9    473.33
# 11 -7038.01
# 13 -8214.01
# 14 -6705.01
# 17 -4683.34
# 18 -4661.67
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance
# 0    9507.67
# 1    9496.67
# 2     5107.0
# 4    3401.66
# 5     882.66
# 6   -1501.67
# 8    -796.34
# 10  -7104.34
# 12 -10113.68
# 15  -7481.34
# 16  -7768.34
# 19   -5564.0
# avg_win 1429.25
# avg_loss -2238.1666666666665
# count_profit_trades 8
# count_loss_trades 12
# win_rate 0.67
# rrr 0.64
#   order_type   profit
# 0        buy -5586.67
# 1       sell -9837.33
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance  dayofweek
# 0    9507.67          1
# 1    9496.67          0
# 2     5107.0          2
# 3    6741.33          0
# 4    3401.66          1
# 5     882.66          4
# 6   -1501.67          3
# 7     390.66          2
# 8    -796.34          2
# 9     473.33          3
# 10  -7104.34          0
# 11  -7038.01          0
# 12 -10113.68          3
# 13  -8214.01          3
# 14  -6705.01          4
# 15  -7481.34          3
# 16  -7768.34          1
# 17  -4683.34          4
# 18  -4661.67          4
# 19   -5564.0          4
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance  dayofweek  current_max  drawdown
# 0    9507.67          1      -492.33       0.0
# 1    9496.67          0      -492.33     -11.0
# 2     5107.0          2      -492.33  -4400.67
# 3    6741.33          0      -492.33  -2766.34
# 4    3401.66          1      -492.33  -6106.01
# 5     882.66          4      -492.33  -8625.01
# 6   -1501.67          3      -492.33 -11009.34
# 7     390.66          2      -492.33  -9117.01
# 8    -796.34          2      -492.33 -10304.01
# 9     473.33          3      -492.33  -9034.34
# 10  -7104.34          0      -492.33 -16612.01
# 11  -7038.01          0      -492.33 -16545.68
# 12 -10113.68          3      -492.33 -19621.35
# 13  -8214.01          3      -492.33 -17721.68
# 14  -6705.01          4      -492.33 -16212.68
# 15  -7481.34          3      -492.33 -16989.01
# 16  -7768.34          1      -492.33 -17276.01
# 17  -4683.34          4      -492.33 -14191.01
# 18  -4661.67          4      -492.33 -14169.34
# 19   -5564.0          4      -492.33 -15071.67
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 evaluate_backtest(bt.trades)
#
# File D:\Trading bot\backtester\__init__.py:359, in evaluate_backtest(df_og)
#     356 df['drawdown'] = df['profit_cumulative'] - df['current_max']
#     357 display(df)
# --> 359 fig_drawdown = px.line(df, x='close_time', y=['profit_cumulative', 'current_max'], title='pnl curve')
#     360 display(fig_drawdown)
#     362 fig_drawdown2 = px.line(df, x='close_time', y='drawdown', title='drawdown curve')
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_chart_types.py:270, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, subtitle, template, width, height)
#     221 def line(
#     222     data_frame=None,
#     223     x=None,
#    (...)    264     height=None,
#     265 ) -> go.Figure:
#     266     """
#     267     In a 2D line plot, each row of `data_frame` is represented as a vertex of
#     268     a polyline mark in 2D space.
#     269     """
# --> 270     return make_figure(args=locals(), constructor=go.Scatter)
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_core.py:2491, in make_figure(args, constructor, trace_patch, layout_patch)
#    2488 layout_patch = layout_patch or {}
#    2489 apply_default_cascade(args)
# -> 2491 args = build_dataframe(args, constructor)
#    2492 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2493     args = process_dataframe_hierarchy(args)
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_core.py:1789, in build_dataframe(args, constructor)
#    1787         dtype = v_dtype
#    1788     elif dtype != v_dtype:
# -> 1789         raise ValueError(
#    1790             "Plotly Express cannot process wide-form data with columns of different type."
#    1791         )
#    1792 df_output = df_output.unpivot(
#    1793     index=wide_id_vars,
#    1794     on=wide_value_vars,
#    1795     variable_name=var_name,
#    1796     value_name=value_name,
#    1797 )
#    1798 assert len(df_output.columns) == len(set(df_output.columns)), (
#    1799     "Wide-mode name-inference failure, likely due to a internal bug. "
#    1800     "Please report this to "
#    1801     "https://github.com/plotly/plotly.py/issues/new and we will try to "
#    1802     "replicate and fix it."
#    1803 )
#
# ValueError: Plotly Express cannot process wide-form data with columns of different type.

# %%
pnl_chart = bt.plot_pnl()
pnl_chart

# %%
evaluate_backtest(bt.trades)
# Out:
# biggest_profit 3092.0
# biggest_loss -7570.67
#      state  symbol order_type  volume  open_time open_price close_time  \
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
#
#     balance
# 3   6741.33
# 7    390.66
# 9    473.33
# 11 -7038.01
# 13 -8214.01
# 14 -6705.01
# 17 -4683.34
# 18 -4661.67
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance
# 0    9507.67
# 1    9496.67
# 2     5107.0
# 4    3401.66
# 5     882.66
# 6   -1501.67
# 8    -796.34
# 10  -7104.34
# 12 -10113.68
# 15  -7481.34
# 16  -7768.34
# 19   -5564.0
# avg_win 1429.25
# avg_loss -2238.1666666666665
# count_profit_trades 8
# count_loss_trades 12
# win_rate 0.67
# rrr 0.64
#   order_type   profit
# 0        buy -5586.67
# 1       sell -9837.33
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance  dayofweek
# 0    9507.67          1
# 1    9496.67          0
# 2     5107.0          2
# 3    6741.33          0
# 4    3401.66          1
# 5     882.66          4
# 6   -1501.67          3
# 7     390.66          2
# 8    -796.34          2
# 9     473.33          3
# 10  -7104.34          0
# 11  -7038.01          0
# 12 -10113.68          3
# 13  -8214.01          3
# 14  -6705.01          4
# 15  -7481.34          3
# 16  -7768.34          1
# 17  -4683.34          4
# 18  -4661.67          4
# 19   -5564.0          4
#      state  symbol order_type  volume  open_time open_price close_time  \
# 0   closed  USDJPY       sell  100000 2023-02-06    132.448 2023-03-14
# 1   closed  USDJPY        buy  100000 2023-03-16    133.373 2023-04-03
# 2   closed  USDJPY       sell  100000 2023-04-17    133.802 2023-07-12
# 3   closed  USDJPY        buy  100000 2023-07-13    138.456 2023-07-31
# 4   closed  USDJPY       sell  100000 2023-08-03    143.324 2023-11-21
# 5   closed  USDJPY        buy  100000 2023-11-22    148.372 2024-01-05
# 6   closed  USDJPY       sell  100000 2024-01-11     145.74 2024-03-07
# 7   closed  USDJPY        buy  100000 2024-03-08     147.96 2024-03-20
# 8   closed  USDJPY       sell  100000 2024-04-11    153.079 2024-06-05
# 9   closed  USDJPY       sell  100000 2024-06-20     158.08 2024-07-18
# 10  closed  USDJPY        buy  100000 2024-07-19    157.354 2024-09-02
# 11  closed  USDJPY        buy  100000 2024-09-05    143.728 2024-09-23
# 12  closed  USDJPY       sell  100000 2024-10-03    146.455 2024-11-28
# 13  closed  USDJPY        buy  100000 2024-12-02     149.58 2024-12-12
# 14  closed  USDJPY       sell  100000 2024-12-20    157.416 2025-01-17
# 15  closed  USDJPY        buy  100000 2025-01-21    155.563 2025-02-13
# 16  closed  USDJPY        buy  100000 2025-02-21     149.62 2025-03-18
# 17  closed  USDJPY       sell  100000 2025-03-25    150.691 2025-04-04
# 18  closed  USDJPY        buy  100000 2025-04-07     145.34 2025-05-02
# 19  closed  USDJPY       sell  100000 2025-05-09    145.914 2025-07-25
#
#    close_price sl tp info   profit commission profit_net profit_cumulative  \
# 0      133.176  0  0   {}  -485.33       -7.0    -492.33           -492.33
# 1      133.367  0  0   {}    -4.00       -7.0      -11.0           -503.33
# 2      140.376  0  0   {} -4382.67       -7.0   -4389.67           -4893.0
# 3      140.918  0  0   {}  1641.33       -7.0    1634.33          -3258.67
# 4      148.323  0  0   {} -3332.67       -7.0   -3339.67          -6598.34
# 5      144.604  0  0   {} -2512.00       -7.0    -2519.0          -9117.34
# 6      149.306  0  0   {} -2377.33       -7.0   -2384.33         -11501.67
# 7      150.809  0  0   {}  1899.33       -7.0    1892.33          -9609.34
# 8      154.849  0  0   {} -1180.00       -7.0    -1187.0         -10796.34
# 9      156.165  0  0   {}  1276.67       -7.0    1269.67          -9526.67
# 10     145.998  0  0   {} -7570.67       -7.0   -7577.67         -17104.34
# 11     143.838  0  0   {}    73.33       -7.0      66.33         -17038.01
# 12     151.058  0  0   {} -3068.67       -7.0   -3075.67         -20113.68
# 13      152.44  0  0   {}  1906.67       -7.0    1899.67         -18214.01
# 14     155.142  0  0   {}  1516.00       -7.0     1509.0         -16705.01
# 15     154.409  0  0   {}  -769.33       -7.0    -776.33         -17481.34
# 16       149.2  0  0   {}  -280.00       -7.0     -287.0         -17768.34
# 17     146.053  0  0   {}  3092.00       -7.0     3085.0         -14683.34
# 18     145.383  0  0   {}    28.67       -7.0      21.67         -14661.67
# 19     147.257  0  0   {}  -895.33       -7.0    -902.33          -15564.0
#
#      balance  dayofweek  current_max  drawdown
# 0    9507.67          1      -492.33       0.0
# 1    9496.67          0      -492.33     -11.0
# 2     5107.0          2      -492.33  -4400.67
# 3    6741.33          0      -492.33  -2766.34
# 4    3401.66          1      -492.33  -6106.01
# 5     882.66          4      -492.33  -8625.01
# 6   -1501.67          3      -492.33 -11009.34
# 7     390.66          2      -492.33  -9117.01
# 8    -796.34          2      -492.33 -10304.01
# 9     473.33          3      -492.33  -9034.34
# 10  -7104.34          0      -492.33 -16612.01
# 11  -7038.01          0      -492.33 -16545.68
# 12 -10113.68          3      -492.33 -19621.35
# 13  -8214.01          3      -492.33 -17721.68
# 14  -6705.01          4      -492.33 -16212.68
# 15  -7481.34          3      -492.33 -16989.01
# 16  -7768.34          1      -492.33 -17276.01
# 17  -4683.34          4      -492.33 -14191.01
# 18  -4661.67          4      -492.33 -14169.34
# 19   -5564.0          4      -492.33 -15071.67
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 evaluate_backtest(bt.trades)
#
# File D:\Trading bot\backtester\__init__.py:359, in evaluate_backtest(df_og)
#     356 df['drawdown'] = df['profit_cumulative'] - df['current_max']
#     357 display(df)
# --> 359 fig_drawdown = px.line(df, x='close_time', y=['profit_cumulative', 'current_max'], title='pnl curve')
#     360 display(fig_drawdown)
#     362 fig_drawdown2 = px.line(df, x='close_time', y='drawdown', title='drawdown curve')
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_chart_types.py:270, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, subtitle, template, width, height)
#     221 def line(
#     222     data_frame=None,
#     223     x=None,
#    (...)    264     height=None,
#     265 ) -> go.Figure:
#     266     """
#     267     In a 2D line plot, each row of `data_frame` is represented as a vertex of
#     268     a polyline mark in 2D space.
#     269     """
# --> 270     return make_figure(args=locals(), constructor=go.Scatter)
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_core.py:2491, in make_figure(args, constructor, trace_patch, layout_patch)
#    2488 layout_patch = layout_patch or {}
#    2489 apply_default_cascade(args)
# -> 2491 args = build_dataframe(args, constructor)
#    2492 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2493     args = process_dataframe_hierarchy(args)
#
# File d:\Trading bot\bot_evn\Lib\site-packages\plotly\express\_core.py:1789, in build_dataframe(args, constructor)
#    1787         dtype = v_dtype
#    1788     elif dtype != v_dtype:
# -> 1789         raise ValueError(
#    1790             "Plotly Express cannot process wide-form data with columns of different type."
#    1791         )
#    1792 df_output = df_output.unpivot(
#    1793     index=wide_id_vars,
#    1794     on=wide_value_vars,
#    1795     variable_name=var_name,
#    1796     value_name=value_name,
#    1797 )
#    1798 assert len(df_output.columns) == len(set(df_output.columns)), (
#    1799     "Wide-mode name-inference failure, likely due to a internal bug. "
#    1800     "Please report this to "
#    1801     "https://github.com/plotly/plotly.py/issues/new and we will try to "
#    1802     "replicate and fix it."
#    1803 )
#
# ValueError: Plotly Express cannot process wide-form data with columns of different type.
